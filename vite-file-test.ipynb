# %% [markdown]
# # Print a Message to the Output Pane
# Write code to print a simple message, such as 'Hello, Visual Studio Code!', to the output pane.

# %%
# Print a simple message
def hello_vscode():
    print('Hello, Visual Studio Code!')
hello_vscode()

# %% [markdown]
# # Display Output in Visual Studio Code
# Run the code cell above and observe the output in the Output pane of Visual Studio Code.

# %% [markdown]
# # Check Output in Integrated Terminal
# Optionally, run a script from the integrated terminal and verify that the output appears as expected.
